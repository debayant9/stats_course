# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                    NaN                NaN            NaN               NaN
# 1                    NaN                NaN            NaN               NaN
# 2                    NaN                NaN            NaN               NaN
# 3                    NaN                NaN            NaN               NaN
# 4                    NaN                NaN            NaN               NaN
# 5                    NaN                NaN            NaN               NaN
# 6                    NaN                NaN            NaN               NaN
# 7                    NaN                NaN            NaN               NaN
# 8                    NaN                NaN            NaN               NaN
# 9                    NaN                NaN            NaN               NaN
# 10                   NaN                NaN            NaN               NaN
# 11                   NaN                NaN            NaN               NaN
# 12                   NaN                NaN            NaN               NaN
# 13                   NaN                NaN            NaN               NaN
# 14                   NaN                NaN            NaN               NaN
# 15                   NaN                NaN            NaN               NaN
# 16                   NaN                NaN            NaN               NaN
# 17                   NaN                NaN            NaN               NaN
# 18                   NaN                NaN            NaN               NaN
# 19                   NaN                NaN            NaN               NaN
# 20                   NaN                NaN            NaN               NaN
# 21                   NaN                NaN            NaN               NaN
# 22                   NaN                NaN            NaN               NaN
# 23                   NaN                NaN            NaN               NaN
# 24                   NaN                NaN            NaN               NaN
# 25                   NaN                NaN            NaN               NaN
# 26                   NaN                NaN            NaN               NaN
# 27                   NaN                NaN            NaN               NaN
# 28                   NaN                NaN            NaN               NaN
# 29                   NaN                NaN            NaN               NaN
# ...                  ...                ...            ...               ...
# 39687                NaN                NaN            NaN               NaN
# 39688                NaN                NaN            NaN               NaN
# 39689                NaN                NaN            NaN               NaN
# 39690                NaN                NaN            NaN               NaN
# 39691                NaN                NaN            NaN               NaN
# 39692                NaN                NaN            NaN               NaN
# 39693                NaN                NaN            NaN               NaN
# 39694                NaN                NaN            NaN               NaN
# 39695                NaN                NaN            NaN               NaN
# 39696                NaN                NaN            NaN               NaN
# 39697                NaN                NaN            NaN               NaN
# 39698                NaN                NaN            NaN               NaN
# 39699                NaN                NaN            NaN               NaN
# 39700                NaN                NaN            NaN               NaN
# 39701                NaN                NaN            NaN               NaN
# 39702                NaN                NaN            NaN               NaN
# 39703                NaN                NaN            NaN               NaN
# 39704                NaN                NaN            NaN               NaN
# 39705                NaN                NaN            NaN               NaN
# 39706                NaN                NaN            NaN               NaN
# 39707                NaN                NaN            NaN               NaN
# 39708                NaN                NaN            NaN               NaN
# 39709                NaN                NaN            NaN               NaN
# 39710                NaN                NaN            NaN               NaN
# 39711                NaN                NaN            NaN               NaN
# 39712                NaN                NaN            NaN               NaN
# 39713                NaN                NaN            NaN               NaN
# 39714                NaN                NaN            NaN               NaN
# 39715                NaN                NaN            NaN               NaN
# 39716                NaN                NaN            NaN               NaN
#
#       pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                      0.0       0.0             NaN               NaN
# 1                      0.0       0.0             NaN               NaN
# 2                      0.0       0.0             NaN               NaN
# 3                      0.0       0.0             NaN               NaN
# 4                      0.0       0.0             NaN               NaN
# 5                      0.0       0.0             NaN               NaN
# 6                      0.0       0.0             NaN               NaN
# 7                      0.0       0.0             NaN               NaN
# 8                      0.0       0.0             NaN               NaN
# 9                      0.0       0.0             NaN               NaN
# 10                     0.0       0.0             NaN               NaN
# 11                     0.0       0.0             NaN               NaN
# 12                     0.0       0.0             NaN               NaN
# 13                     0.0       0.0             NaN               NaN
# 14                     0.0       0.0             NaN               NaN
# 15                     0.0       0.0             NaN               NaN
# 16                     0.0       0.0             NaN               NaN
# 17                     0.0       0.0             NaN               NaN
# 18                     0.0       0.0             NaN               NaN
# 19                     0.0       0.0             NaN               NaN
# 20                     0.0       0.0             NaN               NaN
# 21                     0.0       0.0             NaN               NaN
# 22                     0.0       0.0             NaN               NaN
# 23                     0.0       0.0             NaN               NaN
# 24                     0.0       0.0             NaN               NaN
# 25                     0.0       0.0             NaN               NaN
# 26                     0.0       0.0             NaN               NaN
# 27                     0.0       0.0             NaN               NaN
# 28                     0.0       0.0             NaN               NaN
# 29                     0.0       0.0             NaN               NaN
# ...                    ...       ...             ...               ...
# 39687                  NaN       NaN             NaN               NaN
# 39688                  NaN       NaN             NaN               NaN
# 39689                  NaN       NaN             NaN               NaN
# 39690                  NaN       NaN             NaN               NaN
# 39691                  NaN       NaN             NaN               NaN
# 39692                  NaN       NaN             NaN               NaN
# 39693                  NaN       NaN             NaN               NaN
# 39694                  NaN       NaN             NaN               NaN
# 39695                  NaN       NaN             NaN               NaN
# 39696                  NaN       NaN             NaN               NaN
# 39697                  NaN       NaN             NaN               NaN
# 39698                  NaN       NaN             NaN               NaN
# 39699                  NaN       NaN             NaN               NaN
# 39700                  NaN       NaN             NaN               NaN
# 39701                  NaN       NaN             NaN               NaN
# 39702                  NaN       NaN             NaN               NaN
# 39703                  NaN       NaN             NaN               NaN
# 39704                  NaN       NaN             NaN               NaN
# 39705                  NaN       NaN             NaN               NaN
# 39706                  NaN       NaN             NaN               NaN
# 39707                  NaN       NaN             NaN               NaN
# 39708                  NaN       NaN             NaN               NaN
# 39709                  NaN       NaN             NaN               NaN
# 39710                  NaN       NaN             NaN               NaN
# 39711                  NaN       NaN             NaN               NaN
# 39712                  NaN       NaN             NaN               NaN
# 39713                  NaN       NaN             NaN               NaN
# 39714                  NaN       NaN             NaN               NaN
# 39715                  NaN       NaN             NaN               NaN
# 39716                  NaN       NaN             NaN               NaN
#
#       total_bc_limit total_il_high_credit_limit
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN
# 5                NaN                        NaN
# 6                NaN                        NaN
# 7                NaN                        NaN
# 8                NaN                        NaN
# 9                NaN                        NaN
# 10               NaN                        NaN
# 11               NaN                        NaN
# 12               NaN                        NaN
# 13               NaN                        NaN
# 14               NaN                        NaN
# 15               NaN                        NaN
# 16               NaN                        NaN
# 17               NaN                        NaN
# 18               NaN                        NaN
# 19               NaN                        NaN
# 20               NaN                        NaN
# 21               NaN                        NaN
# 22               NaN                        NaN
# 23               NaN                        NaN
# 24               NaN                        NaN
# 25               NaN                        NaN
# 26               NaN                        NaN
# 27               NaN                        NaN
# 28               NaN                        NaN
# 29               NaN                        NaN
# ...              ...                        ...
# 39687            NaN                        NaN
# 39688            NaN                        NaN
# 39689            NaN                        NaN
# 39690            NaN                        NaN
# 39691            NaN                        NaN
# 39692            NaN                        NaN
# 39693            NaN                        NaN
# 39694            NaN                        NaN
# 39695            NaN                        NaN
# 39696            NaN                        NaN
# 39697            NaN                        NaN
# 39698            NaN                        NaN
# 39699            NaN                        NaN
# 39700            NaN                        NaN
# 39701            NaN                        NaN
# 39702            NaN                        NaN
# 39703            NaN                        NaN
# 39704            NaN                        NaN
# 39705            NaN                        NaN
# 39706            NaN                        NaN
# 39707            NaN                        NaN
# 39708            NaN                        NaN
# 39709            NaN                        NaN
# 39710            NaN                        NaN
# 39711            NaN                        NaN
# 39712            NaN                        NaN
# 39713            NaN                        NaN
# 39714            NaN                        NaN
# 39715            NaN                        NaN
# 39716            NaN                        NaN
#
# [39717 rows x 111 columns]

# %%
po.info()
po.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB
# (39717, 111)

# %%
po = po.dropna(axis=1, how='all')
po.shape
# Out:
# (39717, 57)

# %%
# FILLING NULL VALUES IN REVOL_UTIL WITH 0% SINCE MOST OF REVOL_BAL CORRESPONDING IS 0
po.dtypes
po['revol_util'].tail(20)
po[po['revol_util'].isnull()]
po.loc[po['revol_util'].isnull(), ['revol_util']] = "0%"
po['revol_util'].isnull().sum()
# Out:
# 0

# %%
#Converting int_rate column from string to float
po.int_rate = po.int_rate.apply(lambda x: x.replace('%',''))
po.int_rate = pd.to_numeric(po.int_rate)

# %%
po.revol_util= po.revol_util.apply(lambda x: x.replace('%',''))
po.revol_util = pd.to_numeric(po.revol_util)

# %%
po.revol_util
# Out:
# 0        83.70
# 1         9.40
# 2        98.50
# 3        21.00
# 4        53.90
# 5        28.30
# 6        85.60
# 7        87.50
# 8        32.60
# 9        36.50
# 10       20.60
# 11       67.10
# 12       91.70
# 13       43.10
# 14       55.50
# 15       81.50
# 16       70.20
# 17       16.00
# 18       37.73
# 19       23.10
# 20       85.60
# 21       90.30
# 22       82.40
# 23       91.80
# 24       29.70
# 25       93.90
# 26       57.60
# 27       59.50
# 28       37.70
# 29       59.10
#          ...
# 39687    93.40
# 39688    74.10
# 39689    75.80
# 39690     8.10
# 39691    92.30
# 39692    36.60
# 39693    41.10
# 39694    19.50
# 39695     6.80
# 39696    23.30
# 39697    54.40
# 39698    37.60
# 39699    23.90
# 39700    16.50
# 39701    14.40
# 39702    47.10
# 39703     0.00
# 39704     7.80
# 39705    16.90
# 39706    26.30
# 39707    39.20
# 39708    48.60
# 39709    16.10
# 39710     0.60
# 39711    23.00
# 39712    13.10
# 39713    26.90
# 39714    19.40
# 39715     0.70
# 39716    51.50
# Name: revol_util, Length: 39717, dtype: float64

# %%
po.loc[po.emp_length.isnull(),['emp_title','emp_length','annual_inc']]
po.emp_length = po.emp_length.apply(lambda x: x.replace(" years","") if x.notnull() else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-f63865f9b51f> in <module>
#       1 po.loc[po.emp_length.isnull(),['emp_title','emp_length','annual_inc']]
# ----> 2 po.emp_length = po.emp_length.apply(lambda x: x.replace(" years","") if x.notnull() else x)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-64-f63865f9b51f> in <lambda>(x)
#       1 po.loc[po.emp_length.isnull(),['emp_title','emp_length','annual_inc']]
# ----> 2 po.emp_length = po.emp_length.apply(lambda x: x.replace(" years","") if x.notnull() else x)
#
# AttributeError: 'str' object has no attribute 'notnull'

# %%
pochargedoff = po[po.loan_status == "Charged Off"]
pogood = po[po.loan_status == "Fully Paid"]
pocurrent = po[po.loan_status == "Current"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# purp = pochargedoff.loc[:,["loan_status","purpose"]]

# plt.figure(figsize=(10, 6))

# plt.hist(po['purpose'])
# # plt.show()

# %%
purp1 = pd.DataFrame(pochargedoff.purpose.value_counts())
purp1 = purp1.reset_index()
# plt.figure(figsize=(20, 6))
# sns.barplot(x = 'index',y='purpose',data=purp1)
# plt.show
# pochargedoff.purpose.value_counts()
purp1
# Out:
#                  index  purpose
# 0   debt_consolidation     2767
# 1                other      633
# 2          credit_card      542
# 3       small_business      475
# 4     home_improvement      347
# 5       major_purchase      222
# 6                  car      160
# 7              medical      106
# 8              wedding       96
# 9               moving       92
# 10               house       59
# 11         educational       56
# 12            vacation       53
# 13    renewable_energy       19

# %%
purp4 = pd.DataFrame(pochargedoff.grade.value_counts())
purp4 = purp4.reset_index()

# %%
pochargedoff.loan_amnt.describe()
# Out:
# count     5627.000000
# mean     12104.385108
# std       8085.732038
# min        900.000000
# 25%       5600.000000
# 50%      10000.000000
# 75%      16500.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
pochargedoff.dti.describe()
pochargedoff['dti'].quantile(.95)
# Out:
# 23.92

# %%
# According to this dataset, dti is not a factor behind loan defaulting
pogood.dti.describe()
pogood['dti'].quantile(.95)
# Out:
# 23.77

# %%
pogood.loan_amnt.describe()
# Out:
# count    32950.000000
# mean     10866.455994
# std       7199.629493
# min        500.000000
# 25%       5200.000000
# 50%       9600.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
pogood.installment.describe()
# Out:
# count    32950.000000
# mean       320.125232
# std        207.081110
# min         15.690000
# 25%        165.282500
# 50%        275.650000
# 75%        420.735000
# max       1295.210000
# Name: installment, dtype: float64

# %%
pochargedoff.installment.describe()
# Out:
# count    5627.000000
# mean      336.175006
# std       217.051841
# min        22.790000
# 25%       168.555000
# 50%       293.870000
# 75%       457.840000
# max      1305.190000
# Name: installment, dtype: float64

# %%
# SMALL BUSINESS HAS THE HIGHEST RATE OF DEFAULT

#purp2 = pd.DataFrame(pogood.purpose.value_counts())
# purp2 = purp2.reset_index()
# plt.figure(figsize=(20, 6))
# sns.barplot(x = 'index',y='purpose',data=purp2)
# plt.show()
po1 = pd.DataFrame(pogood.purpose.value_counts())
po1.rename(columns={'purpose':'total'}, inplace=True)
po1 = po1.reset_index()
po1
purpose_frame = pd.merge(purp1, po1, on='index', how='inner')
purpose_frame['percentage'] = round(100*(purpose_frame['purpose']/purpose_frame['total']))
purpose_frame.percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-655efb6b0940> in <module>
#      10 po1 = po1.reset_index()
#      11 po1
# ---> 12 purpose_frame = pd.merge(purp1, po1, on='index', how='inner')
#      13 purpose_frame['percentage'] = round(100*(purpose_frame['purpose']/purpose_frame['total']))
#      14 purpose_frame.percentage
#
# NameError: name 'purp1' is not defined

# %%
po4 = pd.DataFrame(pogood.grade.value_counts())
po4.rename(columns={'grade':'total'}, inplace=True)
po4 = po4.reset_index()
po4
purpose_frame = pd.merge(purp4, po4, on='index', how='inner')
purpose_frame['percentage'] = round(100*(purpose_frame['grade']/purpose_frame['total']))
purpose_frame.percentage
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grades'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-b5965478ada1> in <module>
#       4 po4
#       5 purpose_frame = pd.merge(purp4, po4, on='index', how='inner')
# ----> 6 purpose_frame['percentage'] = round(100*(purpose_frame['grades']/purpose_frame['total']))
#       7 purpose_frame.percentage
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'grades'

# %%
pochargedoff.int_rate.describe()
# Out:
# count    5627.000000
# mean       13.820432
# std         3.654413
# min         5.420000
# 25%        11.310000
# 50%        13.610000
# 75%        16.400000
# max        24.400000
# Name: int_rate, dtype: float64

# %%
pogood.int_rate.describe()
# Out:
# count    32950.000000
# mean        11.609761
# std          3.599964
# min          5.420000
# 25%          8.490000
# 50%         11.490000
# 75%         13.990000
# max         24.110000
# Name: int_rate, dtype: float64

# %%
pochargedoff[pochargedoff['revol_util'] == 0]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1400   1051591    1282697       8000         8000      8000.000000
# 1521   1049562    1280778      23000        23000     22975.000000
# 1858   1044994    1275383       3000         3000      3000.000000
# 1921   1036033    1265698       5800         5800      5800.000000
# 2472   1029082    1258445       9750         9750      9750.000000
# 2662   1033569    1263136      22000        22000     21475.000000
# 3208   1023172    1251991       3500         3500      3500.000000
# 4009    60 months     15.96       437.35     C        C5  ...          NaN
# 4127    60 months     18.25       229.77     D        D5  ...          NaN
# 4304    36 months      7.90       219.04     A        A4  ...          NaN
# 4346    36 months      7.90       234.68     A        A4  ...          NaN
# 4714    36 months     14.27       209.29     C        C2  ...          NaN
# 4781    60 months     19.03       908.50     E        E2  ...          NaN
# 4910    36 months     17.27       429.45     D        D3  ...          NaN
# 5175    36 months     11.71       363.84     B        B3  ...          NaN
# 5305    36 months      9.91       161.13     B        B1  ...          NaN
# 5710    36 months     14.27       274.48     C        C2  ...          NaN
# 6389    36 months      7.90       375.49     A        A4  ...          NaN
# 6834    36 months     16.77       426.47     D        D2  ...          NaN
# 6964    60 months     14.27        93.64     C        C2  ...          NaN
# 7161    60 months     10.65       258.82     B        B2  ...          NaN
# 7872    60 months     10.59       258.47     B        B2  ...          NaN
# 8279    60 months     21.74       131.87     F        F5  ...          NaN
# 8648    36 months     16.49       743.39     D        D3  ...          NaN
# 8909    36 months     10.99       114.57     B        B3  ...          NaN
# 9163    36 months     16.89       106.80     D        D4  ...          NaN
# 9961    36 months      7.49       450.98     A        A4  ...          NaN
# 10193   60 months     17.99       888.58     E        E1  ...          NaN
# 10412   36 months      5.99        79.09     A        A2  ...          NaN
# 10526   60 months     11.99       511.51     B        B5  ...          NaN
# ...           ...       ...          ...   ...       ...  ...          ...
# 33164   36 months      7.05       231.75     A        A1  ...          NaN
# 33302   36 months     16.70       532.53     E        E2  ...          NaN
# 33395   36 months     13.57        54.35     C        C3  ...          NaN
# 33503   36 months     14.96       225.20     D        D2  ...          NaN
# 33697   36 months     12.53       167.34     B        B5  ...          NaN
# 34099   36 months     16.35       176.65     E        E1  ...          NaN
# 34268   36 months     14.26        41.17     C        C5  ...          NaN
# 34333   36 months     12.18        90.75     B        B4  ...          NaN
# 34634   36 months     16.35       211.98     E        E1  ...          NaN
# 34687   36 months     12.53       802.36     B        B5  ...          NaN
# 35051   36 months     19.82       229.86     G        G1  ...          NaN
# 35535   36 months     12.53       669.33     B        B5  ...          NaN
# 35745   36 months     16.00       175.79     E        E2  ...          NaN
# 35890   36 months     12.84       268.95     C        C2  ...          NaN
# 35983   36 months     12.53       167.34     C        C1  ...          NaN
# 36209   36 months     16.00        70.32     E        E2  ...          NaN
# 36612   36 months     12.84       255.50     C        C2  ...          NaN
# 36859   36 months     14.11       222.49     D        D1  ...          NaN
# 36945   36 months     12.53       301.20     C        C1  ...          NaN
# 36978   36 months     13.47       379.94     C        C4  ...          NaN
# 37911   36 months     18.21       181.30     F        F4  ...          NaN
# 37991   36 months     12.21       333.15     B        B5  ...          NaN
# 38087   36 months     10.20       388.34     B        B1  ...          NaN
# 38341   36 months     11.78       165.55     C        C1  ...          NaN
# 38457   36 months     16.33       264.91     F        F2  ...          NaN
# 38539   36 months      8.00       219.36     A        A3  ...          NaN
# 38917   36 months     11.34       263.20     C        C2  ...          NaN
# 8279                   0.0       0.0
# 8648                   0.0       0.0
# 8909                   0.0       0.0
# 9163                   0.0       0.0
# 9961                   0.0       0.0
# 10193                  0.0       0.0
# 10412                  0.0       0.0
# 10526                  0.0       0.0
# ...                    ...       ...
# 33164                  0.0       0.0
# 33302                  0.0       0.0
# 33395                  0.0       0.0
# 33503                  0.0       0.0
# 33697                  0.0       0.0
# 34099                  0.0       0.0
# 34268                  0.0       0.0
# 34333                  0.0       0.0
# 34634                  0.0       0.0
# 34687                  0.0       0.0
# 35051                  0.0       0.0
# 35535                  0.0       0.0
# 35745                  0.0       0.0
# 35890                  0.0       0.0
# 35983                  0.0       0.0
# 36209                  0.0       0.0
# 36612                  0.0       0.0
# 36859                  0.0       0.0
# 36945                  0.0       0.0
# 36978                  0.0       0.0
# 37911                  0.0       0.0
# 37991                  0.0       0.0
# 38087                  0.0       0.0
# 38341                  0.0       0.0
# 38457                  0.0       0.0
# 38539                  0.0       0.0
# 38917                  0.0       0.0
# 38970                  0.0       0.0
# 39519                  NaN       0.0
# 39640                  NaN       0.0
#
# [160 rows x 57 columns]

# %%
pogood.revol_util.describe()
#pogood[pogood['revol_util'] == 0]
# Out:
# count    32950.000000
# mean        47.482755
# std         28.303322
# min          0.000000
# 25%         23.800000
# 50%         47.500000
# 75%         70.800000
# max         99.900000
# Name: revol_util, dtype: float64

# %%
pochargedoff.total_acc.describe()
# Out:
# count    5627.000000
# mean       21.427581
# std        11.447427
# min         2.000000
# 25%        13.000000
# 50%        20.000000
# 75%        28.000000
# max        74.000000
# Name: total_acc, dtype: float64

# %%
pogood.total_acc.describe()
# Out:
# count    32950.000000
# mean        22.159393
# std         11.418927
# min          2.000000
# 25%         14.000000
# 50%         20.000000
# 75%         29.000000
# max         90.000000
# Name: total_acc, dtype: float64

# %%
pochargedoff.open_acc.describe()
# Out:
# count    5627.000000
# mean        9.178070
# std         4.525937
# min         2.000000
# 25%         6.000000
# 50%         8.000000
# 75%        12.000000
# max        38.000000
# Name: open_acc, dtype: float64

# %%
pogood.open_acc.describe()
# Out:
# count    32950.000000
# mean         9.292049
# std          4.379854
# min          2.000000
# 25%          6.000000
# 50%          9.000000
# 75%         12.000000
# max         44.000000
# Name: open_acc, dtype: float64

# %%
pochargedoff[pochargedoff.verification_status == "Not Verified"]
# Out:
# (2142, 57)

# %%
pogood[pogood.verification_status == "Not Verified"]
# Out:
# (14552, 57)

# %%
pogood.pub_rec.sum()
# Out:
# 1661

# %%
pocurrent.shape
pocurrent.pub_rec.sum()
pocurrent.acc_now_delinq.sum()
pocurrent.chargeoff_within_12_mths.sum()
pocurrent.pub_rec_bankruptcies.sum()
pocurrent.tax_liens.sum()
# Out:
# 0.0

# %%
pochargedoff[pochargedoff.term == " 60 months"].shape
# Out:
# (2400, 57)

# %%
pochargedoff.grade.value_counts()
# Out:
# B    1425
# C    1347
# D    1118
# E     715
# A     602
# F     319
# G     101
# Name: grade, dtype: int64
